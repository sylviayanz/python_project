# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <H1>Data Exploration and Upload

# %%
#import dataset
df = pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv')

# %%
#look at the data
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# 2                Living Environment  2016             9         74
# 3               Common Core Algebra  2016             3          s
# 4               Common Core Algebra  2017             2          s
# ...                             ...   ...           ...        ...
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 0                            s                        s
# 1                            1                      6.3
# 2                            1                     11.1
# 3                            s                        s
# 4                            s                        s
# ...                        ...                      ...
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# 212329                       s                        s
# 212330                       s                        s
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 0                               s                           s
# 1                              15                        93.8
# 2                               8                        88.9
# 3                               s                           s
# 4                               s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above  \
# 0                               s                           s
# 1                               7                        43.8
# 2                               2                        22.2
# 3                               s                           s
# 4                               s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring CR Percent Scoring CR
# 0                     na                 na
# 1                     na                 na
# 2                     na                 na
# 3                     na                 na
# 4                     na                 na
# ...                  ...                ...
# 212326                na                 na
# 212327                na                 na
# 212328                na                 na
# 212329                na                 na
# 212330                na                 na
#
# [212331 rows x 15 columns]

# %%
#look at shape of the data 
df.shape

#212,331 columns and 15 rows
# Out:
# (212331, 15)

# %%
#Display info about the dataframe like how many columns and what data type
df.info()

#most of column not numeric data, can't work with df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212331 entries, 0 to 212330
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   School DBN                   212331 non-null  object
#  1   School Name                  212331 non-null  object
#  2   School Level                 212331 non-null  object
#  3   Regents Exam                 212321 non-null  object
#  4   Year                         212331 non-null  int64
#  5   Total Tested                 212331 non-null  int64
#  6   Mean Score                   212331 non-null  object
#  7   Number Scoring Below 65      212331 non-null  object
#  8   Percent Scoring Below 65     212331 non-null  object
#  9   Number Scoring 65 or Above   212331 non-null  object
#  10  Percent Scoring 65 or Above  212331 non-null  object
#  11  Number Scoring 80 or Above   212331 non-null  object
#  12  Percent Scoring 80 or Above  212331 non-null  object
#  13  Number Scoring CR            212331 non-null  object
#  14  Percent Scoring CR           212331 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 24.3+ MB

# %%
#Display school levels

df["School Level"].unique()

#Looks like including students from elementary, K-8 to High School K-12
# Out:
# array(['K-8', 'High school', 'Junior High-Intermediate-Middle',
#        'Secondary School', 'K-12 all grades', 'Elementary'], dtype=object)

# %%
#Display Regent Exam, including 14 subjects

df["Regents Exam"].unique()
# Out:
# array(['Common Core Algebra', 'Living Environment', 'Common Core English',
#        'Algebra2/Trigonometry', 'Common Core Algebra2',
#        'Common Core Geometry', 'English', 'Geometry',
#        'Global History and Geography', 'Integrated Algebra',
#        'Physical Settings/Chemistry', 'Physical Settings/Earth Science',
#        'U.S. History and Government', 'Physical Settings/Physics', nan],
#       dtype=object)

# %%
#Display all school names
df["School Name"].unique()
# Out:
# array(['P.S. 034 Franklin D. Roosevelt', 'P.S. 140 Nathan Straus',
#        'P.S. 184m Shuang Wen', ..., 'Family Life Academy Charter School',
#        'Harriet Tubman Charter School', 'Icahn Charter School'],
#       dtype=object)

# %%
#1,012 schools in total
df["School Name"].nunique()
# Out:
# 1012

# %%
df["Year"].unique()

#from year 2015-2017
# Out:
# array([2017, 2015, 2016])

# %% [markdown]
# <div style="background-color: pink; padding: 10px">
#
# **Now we know:<br>**
# 1.  This data reflects the scores of students taking high-school level Regents exams in NYC<br>
# 2.  Students take the exam from K-8 to K-12<br>
# 3.  Grades for each of category of Regents were taken over the years 2015-2017<br>
# 4.  Regent Exam include 14 subjects<br>
# 5.  Includes 1,012 schools score data
# </div>

# %% [markdown]
# <div style="background-color: pink; padding: 10px">
#
# **Still need to know:**
# 1. What does 's' mean?
# 2. What does 'CR' mean?
# </div>

# %% [markdown]
# <H1>Search more info

# %% [markdown]
# <div style="background-color: #f2f2f2; padding: 10px">
#
# **Data Source**
#
# This data can be found on NYC OpenData, it's provided by NYC Department of Education.
#
# ->2014-15 To 2016-17 School- Level NYC Regents Report For All Variables report: (https://data.cityofnewyork.us/Education/2014-15-To-2016-17-School-Level-NYC-Regents-Report/csps-2ne9)
#
# **DATA DESCRIPTION:**
#
# This data reflects the scores of students taking high-school level Regents exams.
#
#
# **Data Dictionary:**
#
# The following information can be found at: https://data.cityofnewyork.us/api/views/csps-2ne9/files/3db3f2bd-d8d4-4ab2-b746-42fc56118066?download=true&filename=2014-15_To_2016-17_School_Level_NYC_Regents_Report_For_All_Variables.xlsx
#
# 1) Testing and score data includes all administrations of the Regents exam: January, June, and August. It reports the highest score for each student for each Regents exam for each school year. Non-numeric marks are dropped from the data.
#
# 2) Due to ongoing updates to the data, including late uploads of Regents scores from prior test administrations, the numbers reported will likely change in subsequent years' reports.
#
# 3) School DBNs are as of June 30th for each school year.
# <div style="background-color: yellow; padding: 10px">
# 4) Pursuant to the legislation and in accordance with the Family Educational Rights and Privacy Act (FERPA), rows with 5 or fewer students have been replaced with an "s". In addition, other rows have been replaced with an "s" when they could reveal, through addition or subtraction, the underlying numbers that have been redacted.
#
# 5) CR: College & career readiness scores only apply to ELA and Math exams. The CR benchmarks on Regents exams include: - English Regents exam score of 75+ - Any Math Regents exam score of 80+ - Common Core-aligned Algebra I or Geometry Regents exam score of 70+ or Algebra II/Trigonometry exam score of 65+
# </div>
# 6) Students with disabilities are defined as any child receiving an IEP as of the end of the school year.
#
# 7) Data on students with disabilities and English language learners are as of June 30th for each school year.
#
# 8) Multiple Race Categories Not Represented columns includes students who do not report their race, as well as students reported as Native American or Multi-Racial.
# </div>

# %% [markdown]
# <H1>Data Cleaning

# %%
#count missing data by column

df.isnull().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %% [markdown]
# <div style="background-color: orange; padding: 10px"><strong>
# There're many 'na' didn't count as missing data.<br>
# Let's try isna() function
# </div></strong>

# %%
# Count 'na' in each column
df.isna().sum()
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %% [markdown]
# <div style="background-color: orange; padding: 10px"><strong>
# Still not working, why???<br>
# Try another way...
# </div></strong>

# %%
#Total occurrences of 'na' in the DataFrame:
#set up variable

na_count = (df == 'na').sum()
na_count
# Out:
# School DBN                          0
# School Name                         0
# School Level                        0
# Regents Exam                        0
# Year                                0
# Total Tested                        0
# Mean Score                          0
# Number Scoring Below 65             0
# Percent Scoring Below 65            0
# Number Scoring 65 or Above          0
# Percent Scoring 65 or Above         0
# Number Scoring 80 or Above          0
# Percent Scoring 80 or Above         0
# Number Scoring CR              142680
# Percent Scoring CR             142680
# dtype: int64

# %% [markdown]
# <div style="background-color: orange; padding: 10px"><strong>
# There're too many missing data on 'Number Scoring CR' and 'Percent Scoring CR' columns<br>
# That'll be better to drop them
# </div></strong>

# %%
#drop columns
df.drop(['Number Scoring CR', 'Percent Scoring CR'], axis=1, inplace = True)

# %%
#check dataset now
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# 2                Living Environment  2016             9         74
# 3               Common Core Algebra  2016             3          s
# 4               Common Core Algebra  2017             2          s
# ...                             ...   ...           ...        ...
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 0                            s                        s
# 1                            1                      6.3
# 2                            1                     11.1
# 3                            s                        s
# 4                            s                        s
# ...                        ...                      ...
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# 212329                       s                        s
# 212330                       s                        s
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 0                               s                           s
# 1                              15                        93.8
# 2                               8                        88.9
# 3                               s                           s
# 4                               s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above
# 0                               s                           s
# 1                               7                        43.8
# 2                               2                        22.2
# 3                               s                           s
# 4                               s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
# [212331 rows x 13 columns]

# %%
#drops all missing values
df.dropna()
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# 2                Living Environment  2016             9         74
# 3               Common Core Algebra  2016             3          s
# 4               Common Core Algebra  2017             2          s
# ...                             ...   ...           ...        ...
# 212326           Living Environment  2016             8          s
# 212327           Living Environment  2016             5          s
# 212328           Living Environment  2017             6          s
# 212329           Living Environment  2017             4          s
# 212330  U.S. History and Government  2015             1          s
#
#        Number Scoring Below 65 Percent Scoring Below 65  \
# 0                            s                        s
# 1                            1                      6.3
# 2                            1                     11.1
# 3                            s                        s
# 4                            s                        s
# ...                        ...                      ...
# 212326                       s                        s
# 212327                       s                        s
# 212328                       s                        s
# 212329                       s                        s
# 212330                       s                        s
#
#        Number Scoring 65 or Above Percent Scoring 65 or Above  \
# 0                               s                           s
# 1                              15                        93.8
# 2                               8                        88.9
# 3                               s                           s
# 4                               s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
#        Number Scoring 80 or Above Percent Scoring 80 or Above
# 0                               s                           s
# 1                               7                        43.8
# 2                               2                        22.2
# 3                               s                           s
# 4                               s                           s
# ...                           ...                         ...
# 212326                          s                           s
# 212327                          s                           s
# 212328                          s                           s
# 212329                          s                           s
# 212330                          s                           s
#
# [212321 rows x 13 columns]

# %%
#to see the shape of the data now
df.shape
# Out:
# (212331, 13)

# %%
# drop duplicate data

#df2 = df.drop_duplicates()
#df2.shape == df.shape

#there are duplicate rows in df

# %%
#df2

# %%
#Delete columns not necessary for this analysis

# %%
#Re-assign object classified columns as numeric

columns_to_convert = ['Mean Score', 'Number Scoring Below 65', 'Percent Scoring Below 65',
                      'Number Scoring 65 or Above', 'Percent Scoring 65 or Above',
                      'Number Scoring 80 or Above', 'Percent Scoring 80 or Above']

df[columns_to_convert] = df[columns_to_convert].apply(pd.to_numeric, errors='coerce')

#Display the DataFrame after re-assigning the columns as numeric
df.dtypes
# Out:
# School DBN                      object
# School Name                     object
# School Level                    object
# Regents Exam                    object
# Year                             int64
# Total Tested                     int64
# Mean Score                     float64
# Number Scoring Below 65        float64
# Percent Scoring Below 65       float64
# Number Scoring 65 or Above     float64
# Percent Scoring 65 or Above    float64
# Number Scoring 80 or Above     float64
# Percent Scoring 80 or Above    float64
# dtype: object

# %% [markdown]
# <div style="background-color: orange; padding: 10px"><strong>
# Until now, we cleaned data by dropping missing data and delete columns we don't need.<br>
# Also, we convert some object classified columns as numeric, then we can calculate it.
# </div>

# %%
#Describe the numeric data by the five point summary
df.describe().round(2)
# Out:
#             Year  Total Tested  Mean Score  Number Scoring Below 65  \
# count  212331.00     212331.00   137109.00                137109.00
# mean     2015.96         49.36       66.00                    25.14
# std         0.80         93.02       11.29                    37.16
# min      2015.00          1.00       15.00                     0.00
# 25%      2015.00          5.00       58.30                     5.00
# 50%      2016.00         20.00       65.40                    13.00
# 75%      2017.00         57.00       73.40                    31.00
# max      2017.00       1729.00       98.70                   697.00
#
#        Percent Scoring Below 65  Number Scoring 65 or Above  \
# count                 137109.00                   137109.00
# mean                      41.93                       46.44
# std                       28.41                       85.19
# min                        0.00                        0.00
# 25%                       17.50                        8.00
# 50%                       40.20                       21.00
# 75%                       64.00                       52.00
# max                      100.00                     1607.00
#
#        Percent Scoring 65 or Above  Number Scoring 80 or Above  \
# count                    137109.00                   137109.00
# mean                         58.07                       20.51
# std                          28.41                       56.30
# min                           0.00                        0.00
# 25%                          36.00                        1.00
# 50%                          59.80                        5.00
# 75%                          82.50                       18.00
# max                         100.00                     1365.00
#
#        Percent Scoring 80 or Above
# count                    137109.00
# mean                         22.69
# std                          26.16
# min                           0.00
# 25%                           2.20
# 50%                          12.50
# 75%                          34.50
# max                         100.00

# %% [markdown]
# <H1>Initial Analysis of Regents Data

# %% [markdown]
# <div style="background-color: pink; padding: 10px"><strong>
# Look at our task, determine what's our next step:<br>
#
# @the goal of this project is to analyze student test performance<br>
# @pick any school in this dataset as an initial comparison point<br>
# @pick a feature/measure/score<br>
# @compare above school to schools in the entire dataset, schools in a particular borough, or schools in a particular district - you only need to do one additional comparison point (but you’re welcome to do more comparisons if you feel compelled to do so)<br>
# @the analysis should include some descriptive statistics<br>
# @the analysis should include one cleaning task (or more)<br>
# @the analysis should include one visualization (or more)<br>
# @the analysis should include a brief conclusion statement (not more than two or three sentences
#
# </div>

# %% [markdown]
# <div style="background-color: orange; padding: 10px"><strong>
# First of all, decide which school to pick as an initial comparison point
# </div>

# %%
#how many schools are in each school level 
#using groupby

school_count_per_level = df.groupby('School Level')['School Name'].nunique().sort_values(ascending = False)
school_count_per_level
# Out:
# School Level
# High school                        457
# Junior High-Intermediate-Middle    263
# K-8                                161
# Secondary School                    95
# K-12 all grades                     33
# Elementary                           3
# Name: School Name, dtype: int64

# %%
#Create a bar chart to visualize the distribution of schools by school level

plt.figure(figsize=(8, 6))
sns.barplot(x=school_count_per_level.index, y=school_count_per_level.values, palette="viridis")
plt.xlabel('School Level')
plt.ylabel('Number of Schools')
plt.title('Distribution of Schools by School Level')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
#the number of Regents exams taken in each subject

exams_per_subject = df['Regents Exam'].value_counts()
exams_per_subject
# Out:
# Common Core Algebra                29254
# Living Environment                 25539
# U.S. History and Government        20426
# Common Core English                19878
# Global History and Geography       19192
# Physical Settings/Earth Science    15971
# Common Core Geometry               15267
# Physical Settings/Chemistry        11670
# English                            11091
# Integrated Algebra                 11022
# Algebra2/Trigonometry              10788
# Geometry                            8509
# Common Core Algebra2                7915
# Physical Settings/Physics           5799
# Name: Regents Exam, dtype: int64

# %%
#the total number of regents exams taken per year
exams_per_year = df.groupby('Year')['Regents Exam'].count()
exams_per_year
# Out:
# Year
# 2015    72758
# 2016    76123
# 2017    63440
# Name: Regents Exam, dtype: int64

# %%
#the data of Common Core Algebra exams taken

common_core_algebra_exams = df[df['Regents Exam'] == 'Common Core Algebra']
common_core_algebra_exams
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# 8          01M184            P.S. 184m Shuang Wen          K-8
# 9          01M184            P.S. 184m Shuang Wen          K-8
# ...           ...                             ...          ...
# 212319     84X717            Icahn Charter School          K-8
# 212320     84X717            Icahn Charter School          K-8
# 212321     84X717            Icahn Charter School          K-8
# 212322     84X717            Icahn Charter School          K-8
# 212323     84X717            Icahn Charter School          K-8
#
#                Regents Exam  Year  Total Tested  Mean Score  \
# 0       Common Core Algebra  2017             4         NaN
# 3       Common Core Algebra  2016             3         NaN
# 4       Common Core Algebra  2017             2         NaN
# 8       Common Core Algebra  2015            49        78.4
# 9       Common Core Algebra  2016            51        79.0
# ...                     ...   ...           ...         ...
# 212319  Common Core Algebra  2015             2         NaN
# 212320  Common Core Algebra  2016             8        87.9
# 212321  Common Core Algebra  2016             6        87.2
# 212322  Common Core Algebra  2017             6        87.0
# 212323  Common Core Algebra  2017             6        88.3
#
#         Number Scoring Below 65  Percent Scoring Below 65  \
# 0                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# 8                           1.0                       2.0
# 9                           9.0                      17.6
# ...                         ...                       ...
# 212319                      NaN                       NaN
# 212320                      0.0                       0.0
# 212321                      0.0                       0.0
# 212322                      0.0                       0.0
# 212323                      0.0                       0.0
#
#         Number Scoring 65 or Above  Percent Scoring 65 or Above  \
# 0                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# 8                             48.0                         98.0
# 9                             42.0                         82.4
# ...                            ...                          ...
# 212319                         NaN                          NaN
# 212320                         8.0                        100.0
# 212321                         6.0                        100.0
# 212322                         6.0                        100.0
# 212323                         6.0                        100.0
#
#         Number Scoring 80 or Above  Percent Scoring 80 or Above
# 0                              NaN                          NaN
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# 8                             23.0                         46.9
# 9                             33.0                         64.7
# ...                            ...                          ...
# 212319                         NaN                          NaN
# 212320                         7.0                         87.5
# 212321                         6.0                        100.0
# 212322                         6.0                        100.0
# 212323                         5.0                         83.3
#
# [29254 rows x 13 columns]

# %%
#How many Common Core Algebra exam taken per year
common_core_algebra_year = common_core_algebra_exams.groupby('Year')['School DBN'].count()
common_core_algebra_year
# Out:
# Year
# 2015     9126
# 2016     9804
# 2017    10324
# Name: School DBN, dtype: int64

# %%
#add one more column to know boruogh of schools 

df['Borough'] = df['School DBN'].str[2]

borough_mapping = {
    "M": "Manhattan",
    "X": "Bronx",
    "K": "Brooklyn",
    "Q": "Queens",
    "R": "Staten Island"
}
df['Borough'] = df['Borough'].map(borough_mapping)

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested  Mean Score  \
# 0               Common Core Algebra  2017             4         NaN
# 1                Living Environment  2015            16        77.9
# 2                Living Environment  2016             9        74.0
# 3               Common Core Algebra  2016             3         NaN
# 4               Common Core Algebra  2017             2         NaN
# ...                             ...   ...           ...         ...
# 212326           Living Environment  2016             8         NaN
# 212327           Living Environment  2016             5         NaN
# 212328           Living Environment  2017             6         NaN
# 212329           Living Environment  2017             4         NaN
# 212330  U.S. History and Government  2015             1         NaN
#
#         Number Scoring Below 65  Percent Scoring Below 65  \
# 0                           NaN                       NaN
# 1                           1.0                       6.3
# 2                           1.0                      11.1
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 212326                      NaN                       NaN
# 212327                      NaN                       NaN
# 212328                      NaN                       NaN
# 212329                      NaN                       NaN
# 212330                      NaN                       NaN
#
#         Number Scoring 65 or Above  Percent Scoring 65 or Above  \
# 0                              NaN                          NaN
# 1                             15.0                         93.8
# 2                              8.0                         88.9
# 3                              NaN                          NaN
# 4                              NaN                          NaN
# ...                            ...                          ...
# 212326                         NaN                          NaN
# 212327                         NaN                          NaN
# 212328                         NaN                          NaN
# 212329                         NaN                          NaN
# 212330                         NaN                          NaN
#
#         Number Scoring 80 or Above  Percent Scoring 80 or Above    Borough
# 0                              NaN                          NaN  Manhattan
# 1                              7.0                         43.8  Manhattan
# 2                              2.0                         22.2  Manhattan
# 3                              NaN                          NaN  Manhattan
# 4                              NaN                          NaN  Manhattan
# ...                            ...                          ...        ...
# 212326                         NaN                          NaN      Bronx
# 212327                         NaN                          NaN      Bronx
# 212328                         NaN                          NaN      Bronx
# 212329                         NaN                          NaN      Bronx
# 212330                         NaN                          NaN      Bronx
#
# [212331 rows x 14 columns]

# %%
#distribution of Schools Across School Levels in Each Borough

school_count_per_level_borough = df.groupby(['Borough', 'School Level'])['School Name'].nunique().reset_index()

plt.figure(figsize=(12, 6))
sns.barplot(x='Borough', y='School Name', hue='School Level', data=school_count_per_level_borough)
plt.xlabel('Borough')
plt.ylabel('Number of Schools')
plt.title('Distribution of Schools Across School Levels in Each Borough')
plt.legend(title='School Level', title_fontsize='12')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %%
high_school_com_algebra = df[(df['School Level'] == 'High school') & (df['Regents Exam'] == 'Common Core Algebra')]
high_school_com_algebra
# Out:
#        School DBN                                        School Name  \
# 20         01M292                         Orchard Collegiate Academy
# 21         01M292                         Orchard Collegiate Academy
# 22         01M292                         Orchard Collegiate Academy
# 62         01M448                University Neighborhood High School
# 63         01M448                University Neighborhood High School
# ...           ...                                                ...
# 211989     84X553  New Visions Charter High School for the Humani...
# 211990     84X553  New Visions Charter High School for the Humani...
# 211991     84X553  New Visions Charter High School for the Humani...
# 212096     84X581               South Bronx Community Charter School
# 212097     84X581               South Bronx Community Charter School
#
#        School Level         Regents Exam  Year  Total Tested  Mean Score  \
# 20      High school  Common Core Algebra  2015            12        52.3
# 21      High school  Common Core Algebra  2016            50        63.9
# 22      High school  Common Core Algebra  2017            53        67.5
# 62      High school  Common Core Algebra  2015           105        62.6
# 63      High school  Common Core Algebra  2016           148        68.2
# ...             ...                  ...   ...           ...         ...
# 211989  High school  Common Core Algebra  2017           146        66.3
# 211990  High school  Common Core Algebra  2017             2         NaN
# 211991  High school  Common Core Algebra  2017             1         NaN
# 212096  High school  Common Core Algebra  2017             4         NaN
# 212097  High school  Common Core Algebra  2017             8         NaN
#
#         Number Scoring Below 65  Percent Scoring Below 65  \
# 20                         11.0                      91.7
# 21                         25.0                      50.0
# 22                         15.0                      28.3
# 62                         52.0                      49.5
# 63                         42.0                      28.4
# ...                         ...                       ...
# 211989                     48.0                      32.9
# 211990                      NaN                       NaN
# 211991                      NaN                       NaN
# 212096                      NaN                       NaN
# 212097                      NaN                       NaN
#
#         Number Scoring 65 or Above  Percent Scoring 65 or Above  \
# 20                             1.0                          8.3
# 21                            25.0                         50.0
# 22                            38.0                         71.7
# 62                            53.0                         50.5
# 63                           106.0                         71.6
# ...                            ...                          ...
# 211989                        98.0                         67.1
# 211990                         NaN                          NaN
# 211991                         NaN                          NaN
# 212096                         NaN                          NaN
# 212097                         NaN                          NaN
#
#         Number Scoring 80 or Above  Percent Scoring 80 or Above    Borough
# 20                             0.0                          0.0  Manhattan
# 21                             3.0                          6.0  Manhattan
# 22                             6.0                         11.3  Manhattan
# 62                             2.0                          1.9  Manhattan
# 63                            19.0                         12.8  Manhattan
# ...                            ...                          ...        ...
# 211989                         7.0                          4.8      Bronx
# 211990                         NaN                          NaN      Bronx
# 211991                         NaN                          NaN      Bronx
# 212096                         NaN                          NaN      Bronx
# 212097                         NaN                          NaN      Bronx
#
# [15452 rows x 14 columns]

# %%
brooklyn_high = df[
    (df['School Level'] == 'High school') &
    (df['Regents Exam'] == 'Common Core Algebra') &
    (df['Borough'] == 'Brooklyn')
]
brooklyn_high.head(60)
# Out:
#      School DBN                                        School Name  \
# 8474     13K350            Urban Assembly School for Music and Art
# 8475     13K350            Urban Assembly School for Music and Art
# 8476     13K350            Urban Assembly School for Music and Art
# 8509     13K412  Brooklyn Community High School of Communicatio...
# 8510     13K412  Brooklyn Community High School of Communicatio...
# 8511     13K412  Brooklyn Community High School of Communicatio...
# 8545     13K419  Science Skills Center High School for Science,...
# 8546     13K419  Science Skills Center High School for Science,...
# 8547     13K419  Science Skills Center High School for Science,...
# 8583     13K430                     Brooklyn Technical High School
# 8584     13K430                     Brooklyn Technical High School
# 8585     13K430                     Brooklyn Technical High School
# 8616     13K439                 Brooklyn International High School
# 8624     13K483      The Urban Assembly School for Law and Justice
# 8625     13K483      The Urban Assembly School for Law and Justice
# 8626     13K483      The Urban Assembly School for Law and Justice
# 8659     13K499                        ACORN Community High School
# 8660     13K499                        ACORN Community High School
# 8661     13K499                        ACORN Community High School
# 8726     13K553                       Brooklyn Academy High School
# 8727     13K553                       Brooklyn Academy High School
# 8728     13K553                       Brooklyn Academy High School
# 8747     13K575         Bedford Stuyvesant Preparatory High School
# 8748     13K575         Bedford Stuyvesant Preparatory High School
# 8749     13K575         Bedford Stuyvesant Preparatory High School
# 8772     13K595                        Bedford Academy High School
# 8773     13K595                        Bedford Academy High School
# 8774     13K595                        Bedford Academy High School
# 8812     13K605  George Westinghouse Career and Technical Educa...
# 8813     13K605  George Westinghouse Career and Technical Educa...
# 8814     13K605  George Westinghouse Career and Technical Educa...
# 8844     13K616  Brooklyn High School for Leadership and Community
# 8845     13K616  Brooklyn High School for Leadership and Community
# 8846     13K616  Brooklyn High School for Leadership and Community
# 8868     13K657                             Downtown Brooklyn Yabc
# 8869     13K657                             Downtown Brooklyn Yabc
# 8870     13K657                             Downtown Brooklyn Yabc
# 8893     13K670                          Benjamin Banneker Academy
# 8894     13K670                          Benjamin Banneker Academy
# 8895     13K670                          Benjamin Banneker Academy
# 8931     13K674  City Polytechnic High School of Engineering, A...
# 8932     13K674  City Polytechnic High School of Engineering, A...
# 8933     13K674  City Polytechnic High School of Engineering, A...
# 9033     14K322                                Foundations Academy
# 9034     14K322                                Foundations Academy
# 9054     14K449                         Brooklyn Latin School, The
# 9055     14K449                         Brooklyn Latin School, The
# 9056     14K449                         Brooklyn Latin School, The
# 9083     14K454  Green School: An Academy for Environmental Car...
# 9084     14K454  Green School: An Academy for Environmental Car...
# 9085     14K454  Green School: An Academy for Environmental Car...
# 9107     14K474      PROGRESS High School for Professional Careers
# 9108     14K474      PROGRESS High School for Professional Careers
# 9109     14K474      PROGRESS High School for Professional Careers
# 9143     14K477                           School for Legal Studies
# 9144     14K477                           School for Legal Studies
# 9145     14K477                           School for Legal Studies
# 9174     14K478  The High School for Enterprise, Business and T...
# 9175     14K478  The High School for Enterprise, Business and T...
# 9176     14K478  The High School for Enterprise, Business and T...
#
#      School Level         Regents Exam  Year  Total Tested  Mean Score  \
# 8474  High school  Common Core Algebra  2015            86        56.6
# 8475  High school  Common Core Algebra  2016           168        61.3
# 8476  High school  Common Core Algebra  2017           167        61.6
# 8509  High school  Common Core Algebra  2015           109        55.5
# 8510  High school  Common Core Algebra  2016           162        63.9
# 8511  High school  Common Core Algebra  2017           215        62.1
# 8545  High school  Common Core Algebra  2015           124        59.9
# 8546  High school  Common Core Algebra  2016           219        63.3
# 8547  High school  Common Core Algebra  2017           243        67.6
# 8583  High school  Common Core Algebra  2015           298        80.6
# 8584  High school  Common Core Algebra  2016           388        85.5
# 8585  High school  Common Core Algebra  2017           383        87.8
# 8616  High school  Common Core Algebra  2016             2         NaN
# 8624  High school  Common Core Algebra  2015           122        62.6
# 8625  High school  Common Core Algebra  2016           263        66.5
# 8626  High school  Common Core Algebra  2017           186        64.6
# 8659  High school  Common Core Algebra  2015            64        57.4
# 8660  High school  Common Core Algebra  2016           120        58.9
# 8661  High school  Common Core Algebra  2017            82        66.0
# 8726  High school  Common Core Algebra  2015             7        56.7
# 8727  High school  Common Core Algebra  2016            28        61.1
# 8728  High school  Common Core Algebra  2017            16        65.8
# 8747  High school  Common Core Algebra  2015             3         NaN
# 8748  High school  Common Core Algebra  2016            18        59.9
# 8749  High school  Common Core Algebra  2017            39        53.7
# 8772  High school  Common Core Algebra  2015            73        75.3
# 8773  High school  Common Core Algebra  2016            63        77.5
# 8774  High school  Common Core Algebra  2017            54        80.4
# 8812  High school  Common Core Algebra  2015           196        53.4
# 8813  High school  Common Core Algebra  2016           322        60.6
# 8814  High school  Common Core Algebra  2017           371        65.1
# 8844  High school  Common Core Algebra  2015            11        51.8
# 8845  High school  Common Core Algebra  2016            28        53.3
# 8846  High school  Common Core Algebra  2017            39        58.9
# 8868  High school  Common Core Algebra  2015             8        49.3
# 8869  High school  Common Core Algebra  2016            14        54.6
# 8870  High school  Common Core Algebra  2017            21        59.5
# 8893  High school  Common Core Algebra  2015           125        63.1
# 8894  High school  Common Core Algebra  2016           239        72.7
# 8895  High school  Common Core Algebra  2017           287        66.8
# 8931  High school  Common Core Algebra  2015           212        60.9
# 8932  High school  Common Core Algebra  2016           197        65.4
# 8933  High school  Common Core Algebra  2017           138        64.5
# 9033  High school  Common Core Algebra  2015             1         NaN
# 9034  High school  Common Core Algebra  2016            20        55.7
# 9054  High school  Common Core Algebra  2015            87        71.7
# 9055  High school  Common Core Algebra  2016             6        80.2
# 9056  High school  Common Core Algebra  2017             5         NaN
# 9083  High school  Common Core Algebra  2015            77        50.6
# 9084  High school  Common Core Algebra  2016           111        63.6
# 9085  High school  Common Core Algebra  2017           114        63.5
# 9107  High school  Common Core Algebra  2015           253        56.5
# 9108  High school  Common Core Algebra  2016           407        57.4
# 9109  High school  Common Core Algebra  2017           440        59.0
# 9143  High school  Common Core Algebra  2015            89        49.2
# 9144  High school  Common Core Algebra  2016           162        59.0
# 9145  High school  Common Core Algebra  2017           220        63.8
# 9174  High school  Common Core Algebra  2015           221        56.4
# 9175  High school  Common Core Algebra  2016           330        61.5
# 9176  High school  Common Core Algebra  2017           388        62.3
#
#       Number Scoring Below 65  Percent Scoring Below 65  \
# 8474                     63.0                      73.3
# 8475                     96.0                      57.1
# 8476                     90.0                      53.9
# 8509                     90.0                      82.6
# 8510                     72.0                      44.4
# 8511                    111.0                      51.6
# 8545                     78.0                      62.9
# 8546                     98.0                      44.7
# 8547                     78.0                      32.1
# 8583                      1.0                       0.3
# 8584                      0.0                       0.0
# 8585                      0.0                       0.0
# 8616                      NaN                       NaN
# 8624                     59.0                      48.4
# 8625                     86.0                      32.7
# 8626                     80.0                      43.0
# 8659                     49.0                      76.6
# 8660                     75.0                      62.5
# 8661                     28.0                      34.1
# 8726                      7.0                     100.0
# 8727                     16.0                      57.1
# 8728                      7.0                      43.8
# 8747                      NaN                       NaN
# 8748                     10.0                      55.6
# 8749                     34.0                      87.2
# 8772                      2.0                       2.7
# 8773                      3.0                       4.8
# 8774                      1.0                       1.9
# 8812                    174.0                      88.8
# 8813                    187.0                      58.1
# 8814                    144.0                      38.8
# 8844                     11.0                     100.0
# 8845                     26.0                      92.9
# 8846                     25.0                      64.1
# 8868                      8.0                     100.0
# 8869                     12.0                      85.7
# 8870                     10.0                      47.6
# 8893                     56.0                      44.8
# 8894                     39.0                      16.3
# 8895                     97.0                      33.8
# 8931                    121.0                      57.1
# 8932                     85.0                      43.1
# 8933                     55.0                      39.9
# 9033                      NaN                       NaN
# 9034                     14.0                      70.0
# 9054                      3.0                       3.4
# 9055                      0.0                       0.0
# 9056                      NaN                       NaN
# 9083                     71.0                      92.2
# 9084                     51.0                      45.9
# 9085                     54.0                      47.4
# 9107                    191.0                      75.5
# 9108                    293.0                      72.0
# 9109                    261.0                      59.3
# 9143                     86.0                      96.6
# 9144                    101.0                      62.3
# 9145                    105.0                      47.7
# 9174                    159.0                      71.9
# 9175                    176.0                      53.3
# 9176                    193.0                      49.7
#
#       Number Scoring 65 or Above  Percent Scoring 65 or Above  \
# 8474                        23.0                         26.7
# 8475                        72.0                         42.9
# 8476                        77.0                         46.1
# 8509                        19.0                         17.4
# 8510                        90.0                         55.6
# 8511                       104.0                         48.4
# 8545                        46.0                         37.1
# 8546                       121.0                         55.3
# 8547                       165.0                         67.9
# 8583                       297.0                         99.7
# 8584                       388.0                        100.0
# 8585                       383.0                        100.0
# 8616                         NaN                          NaN
# 8624                        63.0                         51.6
# 8625                       177.0                         67.3
# 8626                       106.0                         57.0
# 8659                        15.0                         23.4
# 8660                        45.0                         37.5
# 8661                        54.0                         65.9
# 8726                         0.0                          0.0
# 8727                        12.0                         42.9
# 8728                         9.0                         56.3
# 8747                         NaN                          NaN
# 8748                         8.0                         44.4
# 8749                         5.0                         12.8
# 8772                        71.0                         97.3
# 8773                        60.0                         95.2
# 8774                        53.0                         98.1
# 8812                        22.0                         11.2
# 8813                       135.0                         41.9
# 8814                       227.0                         61.2
# 8844                         0.0                          0.0
# 8845                         2.0                          7.1
# 8846                        14.0                         35.9
# 8868                         0.0                          0.0
# 8869                         2.0                         14.3
# 8870                        11.0                         52.4
# 8893                        69.0                         55.2
# 8894                       200.0                         83.7
# 8895                       190.0                         66.2
# 8931                        91.0                         42.9
# 8932                       112.0                         56.9
# 8933                        83.0                         60.1
# 9033                         NaN                          NaN
# 9034                         6.0                         30.0
# 9054                        84.0                         96.6
# 9055                         6.0                        100.0
# 9056                         NaN                          NaN
# 9083                         6.0                          7.8
# 9084                        60.0                         54.1
# 9085                        60.0                         52.6
# 9107                        62.0                         24.5
# 9108                       114.0                         28.0
# 9109                       179.0                         40.7
# 9143                         3.0                          3.4
# 9144                        61.0                         37.7
# 9145                       115.0                         52.3
# 9174                        62.0                         28.1
# 9175                       154.0                         46.7
# 9176                       195.0                         50.3
#
#       Number Scoring 80 or Above  Percent Scoring 80 or Above   Borough
# 8474                         0.0                          0.0  Brooklyn
# 8475                         1.0                          0.6  Brooklyn
# 8476                         3.0                          1.8  Brooklyn
# 8509                         0.0                          0.0  Brooklyn
# 8510                         2.0                          1.2  Brooklyn
# 8511                         3.0                          1.4  Brooklyn
# 8545                         0.0                          0.0  Brooklyn
# 8546                         5.0                          2.3  Brooklyn
# 8547                        18.0                          7.4  Brooklyn
# 8583                       152.0                         51.0  Brooklyn
# 8584                       348.0                         89.7  Brooklyn
# 8585                       372.0                         97.1  Brooklyn
# 8616                         NaN                          NaN  Brooklyn
# 8624                         1.0                          0.8  Brooklyn
# 8625                        11.0                          4.2  Brooklyn
# 8626                        13.0                          7.0  Brooklyn
# 8659                         0.0                          0.0  Brooklyn
# 8660                         2.0                          1.7  Brooklyn
# 8661                         3.0                          3.7  Brooklyn
# 8726                         0.0                          0.0  Brooklyn
# 8727                         1.0                          3.6  Brooklyn
# 8728                         0.0                          0.0  Brooklyn
# 8747                         NaN                          NaN  Brooklyn
# 8748                         0.0                          0.0  Brooklyn
# 8749                         0.0                          0.0  Brooklyn
# 8772                        15.0                         20.5  Brooklyn
# 8773                        28.0                         44.4  Brooklyn
# 8774                        35.0                         64.8  Brooklyn
# 8812                         1.0                          0.5  Brooklyn
# 8813                         8.0                          2.5  Brooklyn
# 8814                        32.0                          8.6  Brooklyn
# 8844                         0.0                          0.0  Brooklyn
# 8845                         0.0                          0.0  Brooklyn
# 8846                         0.0                          0.0  Brooklyn
# 8868                         0.0                          0.0  Brooklyn
# 8869                         0.0                          0.0  Brooklyn
# 8870                         0.0                          0.0  Brooklyn
# 8893                         0.0                          0.0  Brooklyn
# 8894                        53.0                         22.2  Brooklyn
# 8895                        34.0                         11.8  Brooklyn
# 8931                         0.0                          0.0  Brooklyn
# 8932                        12.0                          6.1  Brooklyn
# 8933                         3.0                          2.2  Brooklyn
# 9033                         NaN                          NaN  Brooklyn
# 9034                         0.0                          0.0  Brooklyn
# 9054                         2.0                          2.3  Brooklyn
# 9055                         2.0                         33.3  Brooklyn
# 9056                         NaN                          NaN  Brooklyn
# 9083                         0.0                          0.0  Brooklyn
# 9084                         4.0                          3.6  Brooklyn
# 9085                         5.0                          4.4  Brooklyn
# 9107                         0.0                          0.0  Brooklyn
# 9108                         0.0                          0.0  Brooklyn
# 9109                        15.0                          3.4  Brooklyn
# 9143                         0.0                          0.0  Brooklyn
# 9144                         0.0                          0.0  Brooklyn
# 9145                        11.0                          5.0  Brooklyn
# 9174                         0.0                          0.0  Brooklyn
# 9175                         7.0                          2.1  Brooklyn
# 9176                        21.0                          5.4  Brooklyn

# %%
high_school_com_algebra_year =  high_school_com_algebra.groupby('Year')['School DBN'].count()
high_school_com_algebra_year
# Out:
# Year
# 2015    4920
# 2016    5294
# 2017    5238
# Name: School DBN, dtype: int64

# %%
 high_school_com_algebra_2016= high_school_com_algebra[high_school_com_algebra['Year'] == 2016]

# %%
#how many high school students join the regent exam of 'Common Core Algebra' in 2016
high_school_com_algebra_2016['Total Tested'].sum()
# Out:
# 413650

# %%
#how many high school students join the regent exam of 'Common Core Algebra' in 2016 in each borough

high_school_com_algebra_2016.groupby('Borough')['Total Tested'].sum()
# Out:
# Borough
# Bronx             83935
# Brooklyn         117340
# Manhattan         75385
# Queens           112000
# Staten Island     24990
# Name: Total Tested, dtype: int64

# %% [markdown]
# <div style="background-color: orange; padding: 10px"><strong>
# Now we know:<br>
# 1. The most school level is High School<br>
# 2. The most taken subject of Regents exam is Common Core Algebra, and the most taken year is 2016 in High School.<br>
# 3. Brooklyn has the most high school in 5 boroughs<br>
# 4. 413,650 high school students join the regent exam of 'Common Core Algebra' in 2016
# </div>

# %% [markdown]
# <H1>Assignment Questions & Analysis

# %% [markdown]
# <div style="background-color: orange; padding: 10px"><strong>
# Depending on research above and my own life experience, I would like to pick a High School in Brooklyn around my neighbor which calls "Bedford Academy High School"
# </div>

# %%
#Pick one individual school and compare results from that school to all other schools.

bahs = high_school_com_algebra[(high_school_com_algebra['School Name'] == 'Bedford Academy High School')]
bahs
# Out:
#        School DBN                  School Name School Level  \
# 8772       13K595  Bedford Academy High School  High school
# 8773       13K595  Bedford Academy High School  High school
# 8774       13K595  Bedford Academy High School  High school
# 35267      13K595  Bedford Academy High School  High school
# 35268      13K595  Bedford Academy High School  High school
# 35269      13K595  Bedford Academy High School  High school
# 35270      13K595  Bedford Academy High School  High school
# 35271      13K595  Bedford Academy High School  High school
# 35272      13K595  Bedford Academy High School  High school
# 76681      13K595  Bedford Academy High School  High school
# 76682      13K595  Bedford Academy High School  High school
# 76683      13K595  Bedford Academy High School  High school
# 76684      13K595  Bedford Academy High School  High school
# 76685      13K595  Bedford Academy High School  High school
# 76686      13K595  Bedford Academy High School  High school
# 76687      13K595  Bedford Academy High School  High school
# 119548     13K595  Bedford Academy High School  High school
# 119549     13K595  Bedford Academy High School  High school
# 119550     13K595  Bedford Academy High School  High school
# 119551     13K595  Bedford Academy High School  High school
# 119552     13K595  Bedford Academy High School  High school
# 119553     13K595  Bedford Academy High School  High school
# 172580     13K595  Bedford Academy High School  High school
# 172581     13K595  Bedford Academy High School  High school
# 172582     13K595  Bedford Academy High School  High school
# 172583     13K595  Bedford Academy High School  High school
# 172584     13K595  Bedford Academy High School  High school
# 172585     13K595  Bedford Academy High School  High school
# 172586     13K595  Bedford Academy High School  High school
# 172587     13K595  Bedford Academy High School  High school
# 172588     13K595  Bedford Academy High School  High school
# 172589     13K595  Bedford Academy High School  High school
# 172590     13K595  Bedford Academy High School  High school
# 172591     13K595  Bedford Academy High School  High school
# 172592     13K595  Bedford Academy High School  High school
# 172593     13K595  Bedford Academy High School  High school
# 172594     13K595  Bedford Academy High School  High school
#
#                Regents Exam  Year  Total Tested  Mean Score  \
# 8772    Common Core Algebra  2015            73        75.3
# 8773    Common Core Algebra  2016            63        77.5
# 8774    Common Core Algebra  2017            54        80.4
# 35267   Common Core Algebra  2015            68         NaN
# 35268   Common Core Algebra  2015             5         NaN
# 35269   Common Core Algebra  2016            49        78.8
# 35270   Common Core Algebra  2016            14        72.9
# 35271   Common Core Algebra  2017            45        81.5
# 35272   Common Core Algebra  2017             9        74.7
# 76681   Common Core Algebra  2015            69         NaN
# 76682   Common Core Algebra  2015             4         NaN
# 76683   Common Core Algebra  2016            59         NaN
# 76684   Common Core Algebra  2016             4         NaN
# 76685   Common Core Algebra  2017             1         NaN
# 76686   Common Core Algebra  2017            49        80.8
# 76687   Common Core Algebra  2017             4         NaN
# 119548  Common Core Algebra  2015            36        74.2
# 119549  Common Core Algebra  2015            37        76.5
# 119550  Common Core Algebra  2016            26        79.0
# 119551  Common Core Algebra  2016            37        76.5
# 119552  Common Core Algebra  2017            34        80.0
# 119553  Common Core Algebra  2017            20        81.0
# 172580  Common Core Algebra  2015             2         NaN
# 172581  Common Core Algebra  2015            60        75.3
# 172582  Common Core Algebra  2015             5         NaN
# 172583  Common Core Algebra  2015             4         NaN
# 172584  Common Core Algebra  2015             2         NaN
# 172585  Common Core Algebra  2016             2         NaN
# 172586  Common Core Algebra  2016            47        76.6
# 172587  Common Core Algebra  2016             5         NaN
# 172588  Common Core Algebra  2016             6        81.3
# 172589  Common Core Algebra  2016             3         NaN
# 172590  Common Core Algebra  2017             2         NaN
# 172591  Common Core Algebra  2017            42        80.3
# 172592  Common Core Algebra  2017             7        80.4
# 172593  Common Core Algebra  2017             2         NaN
# 172594  Common Core Algebra  2017             1         NaN
#
#         Number Scoring Below 65  Percent Scoring Below 65  \
# 8772                        2.0                       2.7
# 8773                        3.0                       4.8
# 8774                        1.0                       1.9
# 35267                       NaN                       NaN
# 35268                       NaN                       NaN
# 35269                       1.0                       2.0
# 35270                       2.0                      14.3
# 35271                       0.0                       0.0
# 35272                       1.0                      11.1
# 76681                       NaN                       NaN
# 76682                       NaN                       NaN
# 76683                       NaN                       NaN
# 76684                       NaN                       NaN
# 76685                       NaN                       NaN
# 76686                       1.0                       2.0
# 76687                       NaN                       NaN
# 119548                      2.0                       5.6
# 119549                      0.0                       0.0
# 119550                      0.0                       0.0
# 119551                      3.0                       8.1
# 119552                      1.0                       2.9
# 119553                      0.0                       0.0
# 172580                      NaN                       NaN
# 172581                      2.0                       3.3
# 172582                      NaN                       NaN
# 172583                      NaN                       NaN
# 172584                      NaN                       NaN
# 172585                      NaN                       NaN
# 172586                      2.0                       4.3
# 172587                      NaN                       NaN
# 172588                      0.0                       0.0
# 172589                      NaN                       NaN
# 172590                      NaN                       NaN
# 172591                      1.0                       2.4
# 172592                      0.0                       0.0
# 172593                      NaN                       NaN
# 172594                      NaN                       NaN
#
#         Number Scoring 65 or Above  Percent Scoring 65 or Above  \
# 8772                          71.0                         97.3
# 8773                          60.0                         95.2
# 8774                          53.0                         98.1
# 35267                          NaN                          NaN
# 35268                          NaN                          NaN
# 35269                         48.0                         98.0
# 35270                         12.0                         85.7
# 35271                         45.0                        100.0
# 35272                          8.0                         88.9
# 76681                          NaN                          NaN
# 76682                          NaN                          NaN
# 76683                          NaN                          NaN
# 76684                          NaN                          NaN
# 76685                          NaN                          NaN
# 76686                         48.0                         98.0
# 76687                          NaN                          NaN
# 119548                        34.0                         94.4
# 119549                        37.0                        100.0
# 119550                        26.0                        100.0
# 119551                        34.0                         91.9
# 119552                        33.0                         97.1
# 119553                        20.0                        100.0
# 172580                         NaN                          NaN
# 172581                        58.0                         96.7
# 172582                         NaN                          NaN
# 172583                         NaN                          NaN
# 172584                         NaN                          NaN
# 172585                         NaN                          NaN
# 172586                        45.0                         95.7
# 172587                         NaN                          NaN
# 172588                         6.0                        100.0
# 172589                         NaN                          NaN
# 172590                         NaN                          NaN
# 172591                        41.0                         97.6
# 172592                         7.0                        100.0
# 172593                         NaN                          NaN
# 172594                         NaN                          NaN
#
#         Number Scoring 80 or Above  Percent Scoring 80 or Above   Borough
# 8772                          15.0                         20.5  Brooklyn
# 8773                          28.0                         44.4  Brooklyn
# 8774                          35.0                         64.8  Brooklyn
# 35267                          NaN                          NaN  Brooklyn
# 35268                          NaN                          NaN  Brooklyn
# 35269                         28.0                         57.1  Brooklyn
# 35270                          0.0                          0.0  Brooklyn
# 35271                         32.0                         71.1  Brooklyn
# 35272                          3.0                         33.3  Brooklyn
# 76681                          NaN                          NaN  Brooklyn
# 76682                          NaN                          NaN  Brooklyn
# 76683                          NaN                          NaN  Brooklyn
# 76684                          NaN                          NaN  Brooklyn
# 76685                          NaN                          NaN  Brooklyn
# 76686                         33.0                         67.3  Brooklyn
# 76687                          NaN                          NaN  Brooklyn
# 119548                         5.0                         13.9  Brooklyn
# 119549                        10.0                         27.0  Brooklyn
# 119550                        12.0                         46.2  Brooklyn
# 119551                        16.0                         43.2  Brooklyn
# 119552                        21.0                         61.8  Brooklyn
# 119553                        14.0                         70.0  Brooklyn
# 172580                         NaN                          NaN  Brooklyn
# 172581                        14.0                         23.3  Brooklyn
# 172582                         NaN                          NaN  Brooklyn
# 172583                         NaN                          NaN  Brooklyn
# 172584                         NaN                          NaN  Brooklyn
# 172585                         NaN                          NaN  Brooklyn
# 172586                        18.0                         38.3  Brooklyn
# 172587                         NaN                          NaN  Brooklyn
# 172588                         4.0                         66.7  Brooklyn
# 172589                         NaN                          NaN  Brooklyn
# 172590                         NaN                          NaN  Brooklyn
# 172591                        27.0                         64.3  Brooklyn
# 172592                         4.0                         57.1  Brooklyn
# 172593                         NaN                          NaN  Brooklyn
# 172594                         NaN                          NaN  Brooklyn

# %%
#the score of 'Bedford Academy High School' for "Common Core Algebra" in 2016

bahs_year_2016 = bahs[bahs['Year'] == 2016]

# Group by 'Year' and calculate the mean for each group, then round to 2 decimal places
bahs_year_mean_2016 = bahs_year_2016.groupby('Year').mean().round(2)
bahs_year_mean_2016
# Out:
#       Total Tested  Mean Score  Number Scoring Below 65  \
# Year
# 2016         26.25       77.51                     1.57
#
#       Percent Scoring Below 65  Number Scoring 65 or Above  \
# Year
# 2016                      4.79                        33.0
#
#       Percent Scoring 65 or Above  Number Scoring 80 or Above  \
# Year
# 2016                        95.21                       15.14
#
#       Percent Scoring 80 or Above
# Year
# 2016                        42.27

# %%
#Create comparison year for all schools for "Common Core Algebra" in 2016

comparison_year = df[(df['Year'] == 2016) &
                     (df['School Level'] == 'High school') & 
                     (df['Regents Exam'] == 'Common Core Algebra')& 
                    (df['School Name'] != 'Bedford Academy High School')]
comparison_year.mean().round(2)
# Out:
# /var/folders/7b/vxx6db214mngjcc97mk085qc0000gn/T/ipykernel_6205/704168170.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   comparison_year.mean().round(2)
# Year                           2016.00
# Total Tested                     78.25
# Mean Score                       64.41
# Number Scoring Below 65          40.94
# Percent Scoring Below 65         45.57
# Number Scoring 65 or Above       61.05
# Percent Scoring 65 or Above      54.44
# Number Scoring 80 or Above       13.07
# Percent Scoring 80 or Above      11.48
# dtype: float64

# %%
#other school score of "Common Core Algebra" in 2016 by borough

other_school = comparison_year.groupby('Borough')
other_school = other_school.mean().round(2)

other_school_1 = other_school.drop(['Year','Total Tested','Number Scoring Below 65', 
                                    'Number Scoring 65 or Above', 'Number Scoring 80 or Above'], axis=1)
other_school_1
# Out:
#                Mean Score  Percent Scoring Below 65  \
# Borough
# Bronx               62.02                     52.92
# Brooklyn            62.56                     50.80
# Manhattan           66.90                     38.85
# Queens              67.22                     36.26
# Staten Island       67.70                     36.23
#
#                Percent Scoring 65 or Above  Percent Scoring 80 or Above
# Borough
# Bronx                                47.08                         6.59
# Brooklyn                             49.21                         7.30
# Manhattan                            61.15                        17.79
# Queens                               63.74                        16.57
# Staten Island                        63.78                        16.66

# %% [markdown]
# <div style="background-color: orange; padding: 10px"><strong>
# Compare to other schools in Brooklyn, students of 'Bedford Academy High School' had better test performance in "Common Core Algebra" in 2016.<br>
# 95.21% students of 'Bedford Academy High School' passed the exam, and 42.27% students got scoring 80 or above. <br>
# Comparing to 'Bedford Academy High School', other students in Brooklyn only 49.21% passed the exam, and 7.30% students got scoring 80 or above.
# </div>

# %%
# drop columns we don't need
bahs_year_2016 = bahs_year_mean_2016[bahs_year_mean_2016.index == 2016]
bahs_year_2016_1 = bahs_year_2016.drop(['Total Tested','Number Scoring Below 65', 'Number Scoring 65 or Above', 
                                        'Number Scoring 80 or Above'], axis=1)
bahs_year_2016_1
# Out:
#       Mean Score  Percent Scoring Below 65  Percent Scoring 65 or Above  \
# Year
# 2016       77.51                      4.79                        95.21
#
#       Percent Scoring 80 or Above
# Year
# 2016                        42.27

# %%
bahs_year_2016['Borough'] = 'Bedford Academy High School'
bahs_year_2016_1
# Out:
#       Mean Score  Percent Scoring Below 65  Percent Scoring 65 or Above  \
# Year
# 2016       77.51                      4.79                        95.21
#
#       Percent Scoring 80 or Above
# Year
# 2016                        42.27

# %% [markdown]
# <H1>Final Summary Comparison of SINGLE SCHOOL to other Schools in Brooklyn and to all NYC schools that tested for Common Core Algebra in 2016

# %%
#combine 2 dataframes
comparison = pd.concat([other_school_1, bahs_year_2016_1], ignore_index=True)
comparison
# Out:
#    Mean Score  Percent Scoring Below 65  Percent Scoring 65 or Above  \
# 0       62.02                     52.92                        47.08
# 1       62.56                     50.80                        49.21
# 2       66.90                     38.85                        61.15
# 3       67.22                     36.26                        63.74
# 4       67.70                     36.23                        63.78
# 5       77.51                      4.79                        95.21
#
#    Percent Scoring 80 or Above
# 0                         6.59
# 1                         7.30
# 2                        17.79
# 3                        16.57
# 4                        16.66
# 5                        42.27

# %%
comparison['Borough or School'] = 'Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island','Bedford Academy High School'
comparison
# Out:
#    Mean Score  Percent Scoring Below 65  Percent Scoring 65 or Above  \
# 0       62.02                     52.92                        47.08
# 1       62.56                     50.80                        49.21
# 2       66.90                     38.85                        61.15
# 3       67.22                     36.26                        63.74
# 4       67.70                     36.23                        63.78
# 5       77.51                      4.79                        95.21
#
#    Percent Scoring 80 or Above            Borough or School
# 0                         6.59                        Bronx
# 1                         7.30                     Brooklyn
# 2                        17.79                    Manhattan
# 3                        16.57                       Queens
# 4                        16.66                Staten Island
# 5                        42.27  Bedford Academy High School

# %%
#set 'Borough or School' as index colimn

comparison.insert(0, 'Borough or School', comparison.pop('Borough or School'))
comparison.set_index('Borough or School', inplace=True)
comparison
# Out:
#                              Mean Score  Percent Scoring Below 65  \
# Borough or School
# Bronx                             62.02                     52.92
# Brooklyn                          62.56                     50.80
# Manhattan                         66.90                     38.85
# Queens                            67.22                     36.26
# Staten Island                     67.70                     36.23
# Bedford Academy High School       77.51                      4.79
#
#                              Percent Scoring 65 or Above  \
# Borough or School
# Bronx                                              47.08
# Brooklyn                                           49.21
# Manhattan                                          61.15
# Queens                                             63.74
# Staten Island                                      63.78
# Bedford Academy High School                        95.21
#
#                              Percent Scoring 80 or Above
# Borough or School
# Bronx                                               6.59
# Brooklyn                                            7.30
# Manhattan                                          17.79
# Queens                                             16.57
# Staten Island                                      16.66
# Bedford Academy High School                        42.27

# %%
# drop columns we don't need

comparison.drop(['Mean Score'], axis=1, inplace=True)

# %%
#Create a visual to show the comparison of student performance
#Stacked Bar Plot

plt.figure(figsize=(10, 6))

# Iterate through each percentage category and plot the bars separately
bottom = None
for col in comparison.columns:
    bars = plt.barh(comparison.index, comparison[col], alpha=0.7, label=col, left=bottom)
    if bottom is None:
        bottom = comparison[col].values
    else:
        bottom += comparison[col].values

# Set the x-axis label to 'Percentage'
plt.xlabel('Percentage')

# Set the y-axis label to 'Borough or School'
plt.ylabel('Borough or School')

# Set the plot title to 'Percentage Comparison'
plt.title('High School Student exam performance of "Common Core Algebra" in 2016')

# Add the legend for each percentage category
plt.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))

# Rotate the plot 90 degrees
plt.gca().invert_yaxis()
plt.xticks(rotation=0)
plt.show()

# %% [markdown]
# <H1>Summary

# %% [markdown]
# <div style="background-color: pink; padding: 10px"><strong>
# 'Bedford Academy High School' had much more percetage students passed regent exam of "Common Core Algebra" in 2016' than average of other schools.<br>
# Staten Island and Queens had better student performance than Bronx and Brooklyn.<br>
# </div>
